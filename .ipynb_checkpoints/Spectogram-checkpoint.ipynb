# %%
import audio as au

import wave
import numpy as np
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
import copy
from scipy.signal import butter, lfilter
import scipy.ndimage

# %%
### Parameters ###
fft_size = 512 # window size for the FFT
step_size = fft_size/16 # distance to slide along the window (in time)
spec_thresh = 4 # threshold for spectrograms (lower filters out more noise)
lowcut = 500 # Hz # Low cut for our butter bandpass filter
highcut = 15000 # Hz # High cut for our butter bandpass filter
# For mels
n_mel_freq_components = 64 # number of mel frequency channels
shorten_factor = 10 # how much should we compress the x-axis (time)
start_freq = 300 # Hz # What frequency to start sampling our melS from 
end_freq = 8000 # Hz # What frequency to stop sampling our melS from Loading the WAV

# %%
# Grab your wav and filter it
mywav = 'tapestry.wav'
rate, data = read(mywav)
data = au.butter_bandpass_filter(data, lowcut, highcut, rate, order=1)
# Only use a short clip for our demo
if np.shape(data)[0]/float(rate) > 10:
    data = data[0:rate*10] 
print('Length in time (s): ', np.shape(data)[0]/float(rate))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-78a737e0199a> in <module>()
#       2 mywav = 'tapestry.wav'
#       3 rate, data = read(mywav)
# ----> 4 data = au.butter_bandpass_filter(data, lowcut, highcut, rate, order=1)
#       5 # Only use a short clip for our demo
#       6 if np.shape(data)[0]/float(rate) > 10:
#
# E:\data\python\3.6\RNN-Ayukngaji\audio.py in butter_bandpass_filter(data, lowcut, highcut, fs, order)
#      39
#      40 def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
# ---> 41     b, a = butter_bandpass(lowcut, highcut, fs, order=order)
#      42     y = lfilter(b, a, data)
#      43     return y
#
# E:\data\python\3.6\RNN-Ayukngaji\audio.py in butter_bandpass(lowcut, highcut, fs, order)
#      35     low = lowcut / nyq
#      36     high = highcut / nyq
# ---> 37     b, a = butter(order, [low, high], btype='band')
#      38     return b, a
#      39
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\scipy\signal\filter_design.py in butter(N, Wn, btype, analog, output)
#    2392     """
#    2393     return iirfilter(N, Wn, btype=btype, analog=analog,
# -> 2394                      output=output, ftype='butter')
#    2395
#    2396
#
# C:\Anaconda3\envs\tensorflow\lib\site-packages\scipy\signal\filter_design.py in iirfilter(N, Wn, rp, rs, btype, analog, ftype, output)
#    1957     if not analog:
#    1958         if numpy.any(Wn <= 0) or numpy.any(Wn >= 1):
# -> 1959             raise ValueError("Digital filter critical frequencies "
#    1960                              "must be 0 < Wn < 1")
#    1961         fs = 2.0
#
# ValueError: Digital filter critical frequencies must be 0 < Wn < 1

# %%
wav_spectrogram = au.pretty_spectrogram(data.astype('float64'), fft_size = fft_size, 
                                   step_size = step_size, log = True, thresh = spec_thresh)

# %%
fig, ax = plt.subplots(nrows=1,ncols=1, figsize=(20,4))
cax = ax.matshow(np.transpose(wav_spectrogram), interpolation='nearest', aspect='auto', cmap=plt.cm.afmhot, origin='lower')
fig.colorbar(cax)
plt.title('Original Spectrogram')
# Out:
# Text(0.5,1.05,'Original Spectrogram')

# %%
#!/usr/bin/env python
# Written by Yu-Jie Lin
# Public Domain
#
# Deps: PyAudio, NumPy, and Matplotlib
# Blog: https://yjlv.blogspot.com/2012/11/frequency-spectrum-of-sound-using.html

from __future__ import print_function

import struct
import wave

import matplotlib.animation as animation
import matplotlib.pyplot as plt
import numpy as np

TITLE = ''
WIDTH = 1280
HEIGHT = 720
FPS = 25.0

nFFT = 512
BUF_SIZE = 4 * nFFT
SAMPLE_SIZE = 2
CHANNELS = 2
RATE = 44100


def animate(i, line, wf, MAX_y):

  N = (int((i + 1) * RATE / FPS) - wf.tell()) / nFFT
  if not N:
    return line,
  N *= nFFT
  data = wf.readframes(N)
  print('{:5.1f}% - V: {:5,d} - A: {:10,d} / {:10,d}'.format(
    100.0 * wf.tell() / wf.getnframes(), i, wf.tell(), wf.getnframes()
  ))

  # Unpack data, LRLRLR...
  y = np.array(struct.unpack("%dh" % (len(data) / SAMPLE_SIZE), data)) / MAX_y
  y_L = y[::2]
  y_R = y[1::2]

  Y_L = np.fft.fft(y_L, nFFT)
  Y_R = np.fft.fft(y_R, nFFT)

  # Sewing FFT of two channels together, DC part uses right channel's
  Y = abs(np.hstack((Y_L[-nFFT / 2:-1], Y_R[:nFFT / 2])))

  line.set_ydata(Y)
  return line,


def init(line):

  # This data is a clear frame for animation
  line.set_ydata(np.zeros(nFFT - 1))
  return line,


def main():

  dpi = plt.rcParams['figure.dpi']
  plt.rcParams['savefig.dpi'] = dpi
  plt.rcParams["figure.figsize"] = (1.0 * WIDTH / dpi, 1.0 * HEIGHT / dpi)

  fig = plt.figure()

  # Frequency range
  x_f = 1.0 * np.arange(-nFFT / 2 + 1, nFFT / 2) / nFFT * RATE
  ax = fig.add_subplot(111, title=TITLE, xlim=(x_f[0], x_f[-1]),
                       ylim=(0, 2 * np.pi * nFFT ** 2 / RATE))
  ax.set_yscale('symlog', linthreshy=nFFT ** 0.5)

  line, = ax.plot(x_f, np.zeros(nFFT - 1))

  # Change x tick labels for left channel
  def change_xlabel(evt):
    labels = [label.get_text().replace(u'\u2212', '')
              for label in ax.get_xticklabels()]
    ax.set_xticklabels(labels)
    fig.canvas.mpl_disconnect(drawid)
  drawid = fig.canvas.mpl_connect('draw_event', change_xlabel)

  MAX_y = 2.0 ** (SAMPLE_SIZE * 8 - 1)
  wf = wave.open('test1-f.wav', 'rb')
  assert wf.getnchannels() == CHANNELS
  assert wf.getsampwidth() == SAMPLE_SIZE
  assert wf.getframerate() == RATE
  frames = wf.getnframes()

  ani = animation.FuncAnimation(
    fig, animate, int(frames / RATE * FPS),
    init_func=lambda: init(line), fargs=(line, wf, MAX_y),
    interval=1000.0 / FPS, blit=True
  )
  #ani.save('temp.mp4', fps=FPS)

  wf.close()


if __name__ == '__main__':
  main()
