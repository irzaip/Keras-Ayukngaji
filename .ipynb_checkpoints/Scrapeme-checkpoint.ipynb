# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'http://jeff560.tripod.com/words.html'

# %%
page = requests.get(url)

# %%
page = page.text

# %%
af = BeautifulSoup(page,"html.parser")

# %%
print(af.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A Collection of Word Oddities and Trivia
#   </title>
#  </head>
#  <body bgcolor="#ffffe1">
#   <center style="font-family: helvetica,arial,sans-serif;">
#    <table border="1" cellpadding="8" cellspacing="0" width="760">
#     <tr>
#      <td>
#       <h1 align="CENTER">
#        <font color="brown">
#         A Collection of Word Oddities and Trivia
#        </font>
#       </h1>
#       <center>
#        <table bgcolor="#FFFFE1" border="0">
#         <tr>
#          <td>
#           <ul>
#            <li>
#             <b>
#              <a href="words1.html">
#               Page 1
#              </a>
#             </b>
#            </li>
#           </ul>
#          </td>
#         </tr>
#        </table>
#       </center>
#      </td>
#     </tr>
#    </table>
#   </center>
#  </body>
# </html>
# - Miscellany
# <li>
#  <b>
#   <a href="words2.html">
#    Page 2
#   </a>
#  </b>
# </li>
# - Miscellany
# <li>
#  <b>
#   <a href="words3.html">
# ...

# %%
a = [type(item) for item in list(af.children)][1]

# %%
a = af.find_all('a')

# %%
# Out:
# <a href="words2.html">Page 2</a>

# %%
import asyncio
loop = asyncio.get_event_loop()

# %%
import aiohttp
import requests

# %%
async def get_content(url):
    try:
        response = requests.get(url)
        print('got it')
    except:
        print("eroor")
        return
    return (response.text)

# %%
c = 1
while True:
    print('count:',c)
    c += 1
    content = loop.run_until_complete(get_content('http://detikarasd.com'))
    print('count_ganjil',c)
# Out:
# count: 1
# eroor
# count_ganjil 2
# count: 2
# eroor
# count_ganjil 3
# count: 3
# eroor
# count_ganjil 4
# count: 4
# eroor
# count_ganjil 5
# count: 5
# eroor
# count_ganjil 6
# count: 6
# eroor
# count_ganjil 7
# count: 7
# eroor
# count_ganjil 8
# count: 8
# eroor
# count_ganjil 9
# count: 9
# eroor
# count_ganjil 10
# count: 10
# eroor
# count_ganjil 11
# count: 11
# eroor
# count_ganjil 12
# count: 12
# eroor
# count_ganjil 13
# count: 13
# eroor
# count_ganjil 14
# count: 14
# eroor
# count_ganjil 15
# count: 15
# eroor
# count_ganjil 16
# count: 16
# eroor
# count_ganjil 17
# count: 17
# eroor
# count_ganjil 18
# count: 18
# eroor
# count_ganjil 19
# count: 19
# eroor
# count_ganjil 20
# count: 20
# eroor
# count_ganjil 21
# count: 21
# eroor
# count_ganjil 22
# count: 22
# eroor
# count_ganjil 23
# count: 23
# eroor
# count_ganjil 24
# count: 24
# eroor
# count_ganjil 25
# count: 25
# eroor
# count_ganjil 26
# count: 26
# eroor
# count_ganjil 27
# count: 27
# eroor
# ...

# %%
import scrapy

# %%
scrapy.
